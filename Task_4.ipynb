# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
train_data=pd.read_csv('/content/drive/MyDrive/data_train.csv')
train_data
# Out:
#          id            img  label  \
# 0     42953  img/42953.png      0
# 1     23058  img/23058.png      0
# 2     13894  img/13894.png      0
# 3     37408  img/37408.png      0
# 4     82403  img/82403.png      0
# ...     ...            ...    ...
# 8495  10423  img/10423.png      1
# 8496  98203  img/98203.png      1
# 8497  36947  img/36947.png      1
# 8498  16492  img/16492.png      1
# 8499  15937  img/15937.png      1
#
#                                                    text
# 0      its their character not their color that matters
# 1     don't be afraid to love again everyone is not ...
# 2                              putting bows on your pet
# 3     i love everything and everybody! except for sq...
# 4     everybody loves chocolate chip cookies, even h...
# ...                                                 ...
# 8495                  nobody wants to hang auschwitz me
# 8496  when god grants you a child after 20 years of ...
# ...

# %%
dev_seen=pd.read_csv('/content/drive/MyDrive/dev_seen.csv')
dev_unseen=pd.read_csv('/content/drive/MyDrive/dev_unseen.csv')
test_seen=pd.read_csv('/content/drive/MyDrive/test_seen.csv')
test_unseen=pd.read_csv('/content/drive/MyDrive/test_unseen.csv')

# %%
dev_seen
# Out:
#         id            img  label  \
# 0     8291  img/08291.png      1
# 1    46971  img/46971.png      1
# 2     3745  img/03745.png      1
# 3    83745  img/83745.png      1
# 4    80243  img/80243.png      1
# ..     ...            ...    ...
# 495  83675  img/83675.png      0
# 496  37198  img/37198.png      0
# 497  48670  img/48670.png      0
# 498   9863  img/09863.png      0
# 499  97320  img/97320.png      0
#
#                                                   text
# 0                white people is this a shooting range
# 1                                bravery at its finest
# 2    your order comes to $37.50 and your white priv...
# 3    it is time.. to send these parasites back to t...
# 4                               mississippi wind chime
# ..                                                 ...
# 495                   i'm gonna be like phelps one day
# 496  when you're so relaxed you can feel yourself g...
# 497  look at this sandwich maker club i found on wi...
# ...

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')


def preprocess_text(text):
    tokens=word_tokenize(text.lower())

    # Remove punctuation
    table=str.maketrans('', '',string.punctuation)
    tokens=[w.translate(table) for w in tokens]

    # Remove remaining tokens that are not alphabetic
    tokens=[word for word in tokens if word.isalpha()]

    # Remove stopwords
    stop_word=set(stopwords.words('english'))
    tokens=[word for word in tokens if not word in stop_words]

    # Lemmatization
    lemmatizer=WordNetLemmatizer()
    tokens=[lemmatizer.lemmatize(word) for word in tokens]


    preprocessed_text=' '.join(tokens)

    return preprocessed_text
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
train_data=train_data.assign(preprocessed_text=train_data['text'].apply(preprocess_text))
train_data
# Out:
#          id            img  label  \
# 0     42953  img/42953.png      0
# 1     23058  img/23058.png      0
# 2     13894  img/13894.png      0
# 3     37408  img/37408.png      0
# 4     82403  img/82403.png      0
# ...     ...            ...    ...
# 8495  10423  img/10423.png      1
# 8496  98203  img/98203.png      1
# 8497  36947  img/36947.png      1
# 8498  16492  img/16492.png      1
# 8499  15937  img/15937.png      1
#
#                                                    text  \
# 0      its their character not their color that matters
# 1     don't be afraid to love again everyone is not ...
# 2                              putting bows on your pet
# 3     i love everything and everybody! except for sq...
# 4     everybody loves chocolate chip cookies, even h...
# ...                                                 ...
# 8495                  nobody wants to hang auschwitz me
# 8496  when god grants you a child after 20 years of ...
# ...

# %%
dev_seen=dev_seen.assign(preprocessed_text=dev_seen['text'].apply(preprocess_text))
dev_unseen=dev_unseen.assign(preprocessed_text=dev_unseen['text'].apply(preprocess_text))
test_seen=test_seen.assign(preprocessed_text=test_seen['text'].apply(preprocess_text))
test_unseen=test_unseen.assign(preprocessed_text=test_unseen['text'].apply(preprocess_text))

# %% [markdown]
# ##HERE I'M PERFORMING SENTIMENT ANALYSIS ON THE TEXT
# ##IM ASSINGING THE FOLLOWING NUMERIC VALUES FOR THE FOLLOWING-
# ##1.POSITIVE:+1
# ##2.NEUTRAL:0
# ##3.NEGATIVE:-1

# %%
from textblob import TextBlob
def analyze_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity < 0:
        return -1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return 1

# %% [markdown]
# ##APPLYING THE VALUES HERE

# %%
train_data['sentiment_analysis']=train_data['preprocessed_text'].apply(analyze_sentiment)

# %%
test_seen['sentiment_analysis']=test_seen['preprocessed_text'].apply(analyze_sentiment)
test_unseen['sentiment_analysis']=test_unseen['preprocessed_text'].apply(analyze_sentiment)
dev_seen['sentiment_analysis']=dev_seen['preprocessed_text'].apply(analyze_sentiment)
dev_unseen['sentiment_analysis']=dev_unseen['preprocessed_text'].apply(analyze_sentiment)

# %%
train_data
# Out:
#          id            img  label  \
# 0     42953  img/42953.png      0
# 1     23058  img/23058.png      0
# 2     13894  img/13894.png      0
# 3     37408  img/37408.png      0
# 4     82403  img/82403.png      0
# ...     ...            ...    ...
# 8495  10423  img/10423.png      1
# 8496  98203  img/98203.png      1
# 8497  36947  img/36947.png      1
# 8498  16492  img/16492.png      1
# 8499  15937  img/15937.png      1
#
#                                                    text  \
# 0      its their character not their color that matters
# 1     don't be afraid to love again everyone is not ...
# 2                              putting bows on your pet
# 3     i love everything and everybody! except for sq...
# 4     everybody loves chocolate chip cookies, even h...
# ...                                                 ...
# 8495                  nobody wants to hang auschwitz me
# 8496  when god grants you a child after 20 years of ...
# ...

# %%
label_counts=train_data['label'].value_counts()
print("label 0:",label_counts[0])
print("label 1:",label_counts[1])
# Out:
# label 0: 5481
# label 1: 3019

# %% [markdown]
# ##Since the label data is imbalanced in the train_data dataframe, I am undersampling the majority class label 1

# %%
import pandas as pd

label_0=train_data[train_data['label']==0]
label_1=train_data[train_data['label']==1]

balanced_label_0_data=label_0.sample(n=3019, random_state=42)
balanced_label_1_data=label_1.sample(n=3019, random_state=42)

balanced_train_data=pd.concat([balanced_label_0_data, balanced_label_1_data])
balanced_train_data=balanced_train_data.sample(frac=1, random_state=42).reset_index(drop=True)


balanced_train_data
# Out:
#          id            img  label  \
# 0     24593  img/24593.png      1
# 1     74602  img/74602.png      0
# 2     25634  img/25634.png      1
# 3     94678  img/94678.png      0
# 4     85023  img/85023.png      0
# ...     ...            ...    ...
# 6033  18397  img/18397.png      1
# 6034  14908  img/14908.png      1
# 6035  50867  img/50867.png      1
# 6036  86509  img/86509.png      1
# 6037  20165  img/20165.png      0
#
#                                                    text  \
# 0     jesus christ may have 2,000 people with 5 loav...
# 1     this is what happens when you don't spank your...
# 2                               google glass locate kfc
# 3                                no one: steven hawking
# 4                      bitch please i'm native american
# ...                                                 ...
# 6033  this is why black people can't advance: ni**er...
# 6034                                  the floor is jews
# ...

# %%
balanced_train_data.drop(columns=['id','img','text'])
# Out:
#       label                                  preprocessed_text  \
# 0         1  jesus christ may people loaf bread fish adolf ...
# 1         0                               happens nt spank kid
# 2         1                            google glass locate kfc
# 3         0                                 one steven hawking
# 4         0                       bitch please native american
# ...     ...                                                ...
# 6033      1    black people ca nt advance ni er holding u back
# 6034      1                                          floor jew
# 6035      1                                   name todd retodd
# 6036      1                         men pig oink louder others
# 6037      0      white liberal treat minority nt vote democrat
#
#       sentiment_analysis
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# ...

# %%
dev_seen.drop(columns=['id','img','text'])
# Out:
#      label                                 preprocessed_text  \
# 0        1                       white people shooting range
# 1        1                                    bravery finest
# 2        1  order come white privilege discount brings total
# 3        1                    time send parasite back desert
# 4        1                            mississippi wind chime
# ..     ...                                               ...
# 495      0                        gon na like phelps one day
# 496      0                        relaxed feel go next level
# 497      0     look sandwich maker club found wish clearance
# 498      0                               diverse group woman
# 499      0   dishwasher broken take back walmart get new one
#
#      sentiment_analysis
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ..                  ...
# 495                   0
# 496                   0
# ...

# %%
dev_unseen.drop(columns=['id','img','text'])
# Out:
#      label                                preprocessed_text  \
# 0        0                                thinking thinking
# 1        0                                   brilliant mind
# 2        0                             pro gamer kill death
# 3        0                                 let end poaching
# 4        0   wife called good husband thats huge compliment
# ..     ...                                              ...
# 535      0                       gon na like phelps one day
# 536      0                       relaxed feel go next level
# 537      0    look sandwich maker club found wish clearance
# 538      0                              diverse group woman
# 539      0  dishwasher broken take back walmart get new one
#
#      sentiment_analysis
# 0                     0
# 1                     1
# 2                     0
# 3                     0
# 4                     1
# ..                  ...
# 535                   0
# 536                   0
# ...

# %%
test_seen.drop(columns=['id','img','text'])
# Out:
#      label                      preprocessed_text  sentiment_analysis
# 0        1               handjobs sold seperately                   0
# 1        1       introducing fidget spinner woman                   0
# 2        1  happy pride month let go beat lesbian                   1
# 3        1            laugh majority u crime rate                   1
# 4        1                       find virgin goat                   0
# ..     ...                                    ...                 ...
# 995      0         mother love child divine thing                   1
# 996      0                             sea monkey                  -1
# 997      0          little miss muffet sat tuffet                  -1
# 998      0                                    row                   0
# 999      0      feeling win fifa game goal behind                   0
#
# [1000 rows x 3 columns]

# %%
test_unseen.drop(columns=['id','img','text'])
# Out:
#       label                                  preprocessed_text  \
# 0         1                                   someone tell bbq
# 1         1                        say white folk nt know cook
# 2         1                                  original derpface
# 3         1                                 okay go piece shit
# 4         1                          xboxone farming simulator
# ...     ...                                                ...
# 1995      0                                 fighting gay right
# 1996      0  feeling finish homework record time extra time...
# 1997      0                            day shook new york city
# 1998      0                      one first prototype atom bomb
# 1999      0      today feel like kinda day wan na freak people
#
#       sentiment_analysis
# 0                      0
# 1                      0
# 2                      1
# 3                      1
# 4                      0
# ...                  ...
# ...

# %% [markdown]
# #PERFORMING UNIMODAL ANALYSIS

# %% [markdown]
# ##LOGISTIC REGRESSION

# %% [markdown]
# ##I AM USING TF-IDF FOR VECTORIZATION OF FEATURE EXTRACTION AND DIMENSIONALITY REDUCTION

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import numpy as np


def train_and_evaluate_model(balanced_train_data,test_unseen_data,test_seen_data,dev_seen_data,dev_unseen_data):

  tfidf_vectorizer=TfidfVectorizer(max_features=10)
  X_train_text=tfidf_vectorizer.fit_transform(balanced_train_data['preprocessed_text'])

  # Combining text and sentiment features for training data
  X_train=np.hstack((X_train_text.toarray(),balanced_train_data['sentiment_analysis'].values.reshape(-1, 1)))

  logistic_regression_model=LogisticRegression(C=1.0, random_state=42)
  logistic_regression_model.fit(X_train, balanced_train_data['label'])


  def evaluate_data(data, name):
    X_data_text=tfidf_vectorizer.transform(data['preprocessed_text'])
    X_data=np.hstack((X_data_text.toarray(), data['sentiment_analysis'].values.reshape(-1, 1)))
    predictions=logistic_regression_model.predict(X_data)
    accuracy=accuracy_score(data['label'],predictions)
    print(f"{name} Accuracy:",accuracy)

  evaluate_data(test_unseen_data,"Test Unseen")
  evaluate_data(test_seen_data,"Test seen")
  evaluate_data(dev_seen_data,"Dev seen")
  evaluate_data(dev_unseen_data,"Dev Unseen")


train_and_evaluate_model(balanced_train_data,test_unseen,test_seen,dev_seen,dev_unseen)
# Out:
# Test Unseen Accuracy: 0.6245
# Test seen Accuracy: 0.544
# Dev seen Accuracy: 0.536
# Dev Unseen Accuracy: 0.6203703703703703

# %% [markdown]
# #DECISION TREES

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import numpy as np

def train_and_evaluate_model(balanced_train_data,test_unseen_data,test_seen_data,dev_seen_data,dev_unseen_data):
    tfidf_vectorizer=TfidfVectorizer(max_features=10)
    X_train_text=tfidf_vectorizer.fit_transform(balanced_train_data['preprocessed_text'])
    X_train=np.hstack((X_train_text.toarray(),balanced_train_data['sentiment_analysis'].values.reshape(-1, 1)))

    #hyperparameters
    hyperparameters={
        'max_depth':20,
        'min_samples_split':2,
        'min_samples_leaf':2,
        'max_features':None
    }

    decision_tree_model=DecisionTreeClassifier(**hyperparameters)
    decision_tree_model.fit(X_train, balanced_train_data['label'])


    def evaluate_data(data, name):
        X_data_text=tfidf_vectorizer.transform(data['preprocessed_text'])
        X_data=np.hstack((X_data_text.toarray(),data['sentiment_analysis'].values.reshape(-1, 1)))
        predictions=decision_tree_model.predict(X_data)
        accuracy=accuracy_score(data['label'],predictions)
        print(f"{name} Accuracy:",accuracy)

    evaluate_data(test_unseen_data,"Test Unseen")
    evaluate_data(test_seen_data,"Test seen")
    evaluate_data(dev_seen_data,"Dev seen")
    evaluate_data(dev_unseen_data,"Dev Unseen")


train_and_evaluate_model(balanced_train_data,test_unseen,test_seen,dev_seen,test_unseen)
# Out:
# Test Unseen Accuracy: 0.62
# Test seen Accuracy: 0.543
# Dev seen Accuracy: 0.532
# Dev Unseen Accuracy: 0.62

# %% [markdown]
# #RANDOM FOREST

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import numpy as np

def train_and_evaluate_model(balanced_train_data,test_unseen_data,test_seen_data,dev_seen_data,dev_unseen_data):

    tfidf_vectorizer=TfidfVectorizer(max_features=10)
    X_train_text=tfidf_vectorizer.fit_transform(balanced_train_data['preprocessed_text'])


    X_train=np.hstack((X_train_text.toarray(),balanced_train_data['sentiment_analysis'].values.reshape(-1, 1)))

    #hyperparameters
    hyperparameters={
        'n_estimators':100,
        'max_depth':20,
        'min_samples_split':2,
        'min_samples_leaf':2,
        'max_features':'auto'
    }

    random_forest_model=RandomForestClassifier(**hyperparameters)
    random_forest_model.fit(X_train balanced_train_data['label'])

    def evaluate_data(data, name):
        X_data_text=tfidf_vectorizer.transform(data['preprocessed_text'])
        X_data=np.hstack((X_data_text.toarray(), data['sentiment_analysis'].values.reshape(-1, 1)))
        predictions=random_forest_model.predict(X_data)
        accuracy=accuracy_score(data['label'],predictions)
        print(f"{name} Accuracy:",accuracy)

    evaluate_data(test_unseen_data,"Test Unseen")
    evaluate_data(test_seen_data,"Test Seen")
    evaluate_data(dev_seen_data,"Dev Seen")
    evaluate_data(dev_unseen_data,"Dev Unseen")


train_and_evaluate_model(balanced_train_data,test_unseen,test_seen,dev_seen,dev_unseen)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Test Unseen Accuracy: 0.6215
# Test Seen Accuracy: 0.545
# Dev Seen Accuracy: 0.538
# Dev Unseen Accuracy: 0.6203703703703703
